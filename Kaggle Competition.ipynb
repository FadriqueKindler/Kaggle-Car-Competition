# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test = pd.read_csv("datamad0819-vehicles/cars_test.csv")
train = pd.read_csv("datamad0819-vehicles/cars_train.csv")

# %%
display(train.head())
train.shape
# Out:
#         Id        city    year manufacturer                     make  \
# 0   559327   baltimore  2006.0          NaN                 Scion tc
# 1  1429566  carbondale  2018.0        dodge              charger sxt
# 2   931606       thumb  1997.0         ford  f 250 2 wheel dr pickup
# 3  1265412      laredo  2003.0          ram                      NaN
# 4  1133731       ocala  2000.0        dodge                     1500
#
#    condition    cylinders fuel  odometer title_status  ... paint_color  \
# 0  excellent  4 cylinders  gas  190000.0        clean  ...        blue
# 1        NaN          NaN  gas       NaN        clean  ...         NaN
# 2       fair          NaN  gas       NaN        clean  ...       white
# 3        NaN  8 cylinders  gas       NaN        clean  ...         NaN
# 4        NaN          NaN  gas       NaN        clean  ...         NaN
#
#          lat       long county_fips     county_name  state_fips  state_code  \
# ...

# %%
train.describe()
# Out:
#                  Id           year      odometer            lat  \
# count  4.699920e+05  468279.000000  3.165270e+05  469992.000000
# mean   8.618454e+05    2004.869185  1.135850e+05      38.778918
# std    4.974450e+05      11.944575  1.400817e+05       5.972400
# min    0.000000e+00    1900.000000  0.000000e+00     -80.218737
# 25%    4.317220e+05    2002.000000  5.800000e+04      34.920500
# 50%    8.622445e+05    2007.000000  1.067000e+05      39.405900
# 75%    1.292693e+06    2012.000000  1.520000e+05      42.559300
# max    1.723061e+06    2019.000000  1.000000e+07      84.668794
#
#                 long    county_fips     state_fips        weather  \
# count  469992.000000  453983.000000  453983.000000  453810.000000
# mean      -93.706408   28459.780131      28.373219      53.787792
# std        16.943175   16043.644693      16.021521       7.803067
# min      -178.989258    1001.000000       1.000000      29.000000
# ...

# %%
train.isnull().sum()
# Out:
# Id                   0
# city                 0
# year              1713
# manufacturer     37260
# make             19078
# condition       191021
# cylinders       188076
# fuel              2844
# odometer        153465
# title_status       708
# transmission      2447
# drive           180334
# size            306775
# type            191640
# paint_color     189613
# lat                  0
# long                 0
# county_fips      16009
# county_name      16009
# state_fips       16009
# state_code       16009
# state_name           0
# weather          16182
# price                0
# dtype: int64

# %%
print(train.columns)
#print(train['drive'].value_counts())
#print(train['transmission'].value_counts())
print(train["odometer"].value_counts())
print(train["odometer"].isnull().sum())
# Out:
# Index(['Id', 'city', 'year', 'manufacturer', 'make', 'condition', 'cylinders',
#        'fuel', 'odometer', 'title_status', 'transmission', 'drive', 'size',
#        'type', 'paint_color', 'lat', 'long', 'county_fips', 'county_name',
#        'state_fips', 'state_code', 'state_name', 'weather', 'price'],
#       dtype='object')
# 150000.0    1868
# 160000.0    1744
# 140000.0    1686
# 200000.0    1594
# 130000.0    1558
#             ...
# 686528.0       1
# 98143.0        1
# 98140.0        1
# 98137.0        1
# 188591.0       1
# Name: odometer, Length: 96200, dtype: int64
# 153465

# %%
train.dropna(subset=["odometer"])
# Out:
#              Id        city    year manufacturer                    make  \
# 0        559327   baltimore  2006.0          NaN                Scion tc
# 5        869261    muskegon  2005.0       toyota                camry se
# 6        229951  abbotsford  2018.0         ford  f150 4x2 xlt super-cab
# 8       1203620      helena  2006.0          ram         2500 diesel 4x4
# 9        203486   rochester  2001.0    chevrolet          silverado 1500
# ...         ...         ...     ...          ...                     ...
# 469987  1505912     olympic  2005.0         ford        f-350 super duty
# 469988  1436810      peoria  2016.0      hyundai                  accent
# 469989   170772  huntsville  2016.0          gmc           sierra 3500hd
# 469990  1649643    greenbay  2016.0      hyundai          santa fe sport
# 469991   882889     detroit  2013.0     chrysler            town country
#
#         condition    cylinders    fuel  odometer title_status  ...        lat  \
# ...

# %%
train["manufacturer"].value_counts()
# Out:
# ford               79933
# chevrolet          60093
# toyota             31722
# honda              24585
# nissan             21925
# dodge              20779
# jeep               20312
# gmc                19255
# ram                15561
# bmw                11840
# chevy              11014
# volkswagen          9111
# hyundai             9087
# chrysler            8658
# subaru              8099
# cadillac            6814
# kia                 6799
# mercedes-benz       6592
# mazda               6380
# buick               6264
# pontiac             6071
# lexus               5523
# acura               4923
# audi                4076
# lincoln             3553
# infiniti            3254
# volvo               2991
# mitsubishi          2945
# mercury             2793
# saturn              2599
# mercedes            1968
# mini                1745
# rover               1517
# vw                  1232
# jaguar              1188
# fiat                 560
# chev                 242
# ...

# %%
train["mean_price"] = train["price"].mean()
train["mean_price"]
# Out:
# 0         90423.881419
# 1         90423.881419
# 2         90423.881419
# 3         90423.881419
# 4         90423.881419
#               ...
# 469987    90423.881419
# 469988    90423.881419
# 469989    90423.881419
# 469990    90423.881419
# 469991    90423.881419
# Name: mean_price, Length: 469992, dtype: float64

# %%
y = train["mean_price"]

# %%
X = train[["Id"]]
